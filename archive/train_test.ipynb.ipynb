# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
#80-10-10 Train/Val/Test split. Random_state stays 42 if not the dataset file would have different results every run
data = pd.read_csv('data-crawling/final_books_dataset_duplicates_removed.csv')
train, validate, test = np.split(data.sample(frac=1, random_state=42),[int(.8*len(data)), int(.9*len(data))])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1825 entries, 5542 to 15795
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   productAsin        1825 non-null   object
#  1   ratingScore        1825 non-null   int64
#  2   reviewTitle        1825 non-null   object
#  3   reviewReaction     317 non-null    object
#  4   reviewDescription  1825 non-null   object
#  5   isVerified         1825 non-null   bool
#  6   category           1825 non-null   object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 101.6+ KB

# %%
test.head(10)
# Out:
#       productAsin  ratingScore  \
# 5542    670062510            4
# 7993   1484707230            5
# 10900  1542046599            5
# 7758   1589255518            5
# 4837    385376715            5
# 6548   9387779262            5
# 4481   B096MWJLNW            5
# 3716     63076098            5
# 10837  1542046599            5
# 6140    578629097            5
#
#                                              reviewTitle  \
# 5542                                           Good item
# 7993                                     Great Series 👍🏻
# 10900                                     Engaging Story
# 7758                              Reading is fundamental
# 4837                 perfect gift for my new grand-baby!
# 6548                                 so nice and helpful
# 4481                                             Amazing
# 3716          Great gift for your Dave Grohl super fans.
# 10837  I enjoyed this writer and am eager to read mor...
# 6140                                            AMAZING!
#
#                      reviewReaction  \
# 5542                            NaN
# 7993                            NaN
# 10900                           NaN
# 7758                            NaN
# 4837   11 people found this helpful
# 6548                            NaN
# 4481    2 people found this helpful
# 3716                            NaN
# 10837                           NaN
# 6140                            NaN
#
#                                        reviewDescription  isVerified  \
# 5542                                           Good item        True
# 7993   Absolutely wonderful book series! I ordered th...        True
# 10900  Before You Go is an engaging read with a weave...        True
# 7758                        My grandson loves this story        True
# 4837   Beautifully illustrated, with healthy & empowe...        True
# 6548                                     My kids love it        True
# 4481   I loved the cover, hard cover and excellent qu...        True
# 3716   My wife is a super fan and was so happy to rec...        True
# 10837  Intense story line that pulls you in and keep ...        True
# 6140   This book is AMAZING! Perfect way to build a c...        True
#
#                   category
# 5542              children
# 7993              children
# 10900              mystery
# 7758              children
# 4837              children
# 6548              children
# 4481   humor_entertainment
# 3716   humor_entertainment
# 10837              mystery
# 6140              children

# %%
test_data = test.reset_index()
test_data = test_data.drop(["index"], axis=1)
test_data.head()
# Out:
#   productAsin  ratingScore                          reviewTitle  \
# 0   670062510            4                            Good item
# 1  1484707230            5                      Great Series 👍🏻
# 2  1542046599            5                       Engaging Story
# 3  1589255518            5               Reading is fundamental
# 4   385376715            5  perfect gift for my new grand-baby!
#
#                  reviewReaction  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4  11 people found this helpful
#
#                                    reviewDescription  isVerified  category
# 0                                          Good item        True  children
# 1  Absolutely wonderful book series! I ordered th...        True  children
# 2  Before You Go is an engaging read with a weave...        True   mystery
# 3                       My grandson loves this story        True  children
# 4  Beautifully illustrated, with healthy & empowe...        True  children

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14595 entries, 217 to 7006
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   productAsin        14595 non-null  object
#  1   ratingScore        14595 non-null  int64
#  2   reviewTitle        14594 non-null  object
#  3   reviewReaction     2442 non-null   object
#  4   reviewDescription  14594 non-null  object
#  5   isVerified         14595 non-null  bool
#  6   category           14595 non-null  object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 812.4+ KB

# %%
train_data = train
train_data["Polarity"] = train_data["ratingScore"].apply(lambda x: 1 if x > 3 else (-1 if x < 3 else 0)) 
train_data.head(10)
# Out:
#       productAsin  ratingScore                                    reviewTitle  \
# 217     451524934            4                    Clear why this is a classic
# 5681    670062510            5                        Read it. It's worth it.
# 13138  1542046599            5                           DEFINITELY read this
# 10557  1542046599            1                             This Book Is Awful
# 17533   399587683            5                     This story was too cute!!!
# 563     451526341            1  I never got it because I cancelled the order.
# 18092   399587683            5                  Fun LA based romantic comedy!
# 2929   B0176M3U10            5                               Such a good read
# 2136   1451673310            5      and Social media is destroyed at any temp
# 3287   1250181909            5                                       Order it
#
#                       reviewReaction  \
# 217    One person found this helpful
# 5681                             NaN
# 13138                            NaN
# 10557  One person found this helpful
# 17533                            NaN
# 563                              NaN
# 18092    2 people found this helpful
# 2929                             NaN
# 2136   One person found this helpful
# 3287                             NaN
#
#                                        reviewDescription  isVerified  \
# 217    A remarkable book. I sometimes hesitate to rea...        True
# 5681   All of my kids had to read this and watch the ...        True
# 13138  I am a big fan of books from each characters v...        True
# 10557  The story was convoluted, repetitive and borin...        True
# 17533  I think I loved this book as much as "The Wedd...        True
# 563    I never got it because I cancelled the order. ...        True
# 18092  I have been waiting to read The Proposal since...        True
# 2929            Loved this book. Trigger warning for DA.        True
# 2136   A warning all the more relevant today and when...        True
# 3287            Love this! Makes bettering yourself fun!        True
#
#                   category  Polarity
# 217    humor_entertainment         1
# 5681              children         1
# 13138              mystery         1
# 10557              mystery        -1
# 17533              romance         1
# 563    humor_entertainment        -1
# 18092              romance         1
# 2929   humor_entertainment         1
# 2136   humor_entertainment         1
# 3287   humor_entertainment         1

# %%
validation_data = validate
validation_data["Polarity"] = validation_data["ratingScore"].apply(lambda x: 1 if x > 3 else (-1 if x < 3 else 0)) 
validation_data.head(10)
# Out:
#       productAsin  ratingScore  \
# 5102    399226907            5
# 13379  1542046599            4
# 11623  1542046599            4
# 6599   9387779262            4
# 3764     63076098            5
# 16235  1984806734            5
# 6410   9387779262            5
# 15499  1984806734            2
# 13705  1542046599            5
# 25      451524934            5
#
#                                              reviewTitle  \
# 5102                                        Classic book
# 13379  This one definitely kept my interest, and kept...
# 11623                                         Good read!
# 6599                                       Fast delivery
# 3764                 Amazing stories from a great person
# 16235                                          Fabulous!
# 6410                                         Great books
# 15499  Throw it into a bonfire on an actual beach for...
# 13705                                         Good read!
# 25                                 1984 and my childhood
#
#                     reviewReaction  \
# 5102                           NaN
# 13379                          NaN
# 11623                          NaN
# 6599   2 people found this helpful
# 3764   3 people found this helpful
# 16235                          NaN
# 6410                           NaN
# 15499  2 people found this helpful
# 13705                          NaN
# 25     6 people found this helpful
#
#                                        reviewDescription  isVerified  \
# 5102   A classic book to teach kids some food, number...        True
# 13379  This one definitely kept my interest, and kept...        True
# 11623  Great story! Interesting how it all comes toge...        True
# 6599   Fast delivery. I would love to give 5 star, ho...        True
# 3764   Been a fan for many years and still Dave has t...        True
# 16235  Sooo well written!  A bit predictable but I lo...        True
# 6410                            My son loves these books        True
# 15499  I read this book to give myself a mindless bre...       False
# 13705  I much enjoyed how the characters were intertw...        True
# 25     Mindlessly mechanical, very few things move he...        True
#
#                   category  Polarity
# 5102              children         1
# 13379              mystery         1
# 11623              mystery         1
# 6599              children         1
# 3764   humor_entertainment         1
# 16235              romance         1
# 6410              children         1
# 15499              romance        -1
# 13705              mystery         1
# 25     humor_entertainment         1

# %%
train_data = train_data.reset_index()
train_data = train_data.drop(["index"], axis=1)

validation_data = validation_data.reset_index()
validation_data = validation_data.drop(["index"], axis=1)


train.to_csv('train.csv')
validate.to_csv('validation.csv')
test.to_csv('test.csv')
train_data.to_csv('train_data_polarity.csv')
validation_data.to_csv('validation_data_polarity.csv')
