# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

# %%
np.random.seed(42)

# %%
# import data, check duplicates

# %%
train_df= pd.read_csv("train_data_polarity.csv", index_col=0)
print(train_df.shape)
train_df.drop_duplicates(inplace=True, ignore_index=True)
print(train_df.shape)
train_df.head()
# Out:
# (14595, 8)
# (14595, 8)
#   productAsin  ratingScore                  reviewTitle  \
# 0   451524934            4  Clear why this is a classic
# 1   670062510            5      Read it. It's worth it.
# 2  1542046599            5         DEFINITELY read this
# 3  1542046599            1           This Book Is Awful
# 4   399587683            5   This story was too cute!!!
#
#                   reviewReaction  \
# 0  One person found this helpful
# 1                            NaN
# 2                            NaN
# 3  One person found this helpful
# 4                            NaN
#
#                                    reviewDescription  isVerified  \
# 0  A remarkable book. I sometimes hesitate to rea...        True
# 1  All of my kids had to read this and watch the ...        True
# 2  I am a big fan of books from each characters v...        True
# 3  The story was convoluted, repetitive and borin...        True
# 4  I think I loved this book as much as "The Wedd...        True
# ...

# %%
val_df = pd.read_csv("validation_data_polarity.csv", index_col=0)
print(val_df.shape)
val_df.drop_duplicates(inplace=True, ignore_index=True)
print(val_df.shape)
val_df.head()
# Out:
# (1824, 8)
# (1824, 8)
#   productAsin  ratingScore                                        reviewTitle  \
# 0   399226907            5                                       Classic book
# 1  1542046599            4  This one definitely kept my interest, and kept...
# 2  1542046599            4                                         Good read!
# 3  9387779262            4                                      Fast delivery
# 4    63076098            5                Amazing stories from a great person
#
#                 reviewReaction  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3  2 people found this helpful
# 4  3 people found this helpful
#
#                                    reviewDescription  isVerified  \
# 0  A classic book to teach kids some food, number...        True
# 1  This one definitely kept my interest, and kept...        True
# 2  Great story! Interesting how it all comes toge...        True
# ...

# %%
test_df = pd.read_csv("test_annotated.csv", index_col=0)
print(test_df.shape)
test_df.drop_duplicates(inplace=True, ignore_index=True)
print(test_df.shape)
test_df.head()
# Out:
# (1825, 10)
# (1825, 10)
#   productAsin  ratingScore                          reviewTitle  \
# 0   670062510            4                            Good item
# 1  1484707230            5                    Great Series ????
# 2  1542046599            5                       Engaging Story
# 3  1589255518            5               Reading is fundamental
# 4   385376715            5  perfect gift for my new grand-baby!
#
#                  reviewReaction  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4  11 people found this helpful
#
#                                    reviewDescription  isVerified  category  \
# 0                                          Good item        True  children
# 1  Absolutely wonderful book series! I ordered th...        True  children
# 2  Before You Go is an engaging read with a weave...        True   mystery
# ...

# %%
# combining train and val
negative_reviews = data[data["polarity"] == -1]
neutral_reviews = data[data["polarity"] == 0]
positive_reviews = data[data["polarity"] == 1]

print(len(negative_reviews))
print(len(neutral_reviews))
print(len(positive_reviews))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-74bd8b286a3b> in <module>
#       1 # preprocessing
# ----> 2 negative_reviews = data[data["polarity"] == -1]
#       3 neutral_reviews = data[data["polarity"] == 0]
#       4 positive_reviews = data[data["polarity"] == 1]
#       5
#
# NameError: name 'data' is not defined

# %%
df_train = train_df.append(val_df, ignore_index=True)
df_train.shape
# Out:
# (16419, 8)

# %%
negative_reviews = df_train[df_train["Polarity"] == -1]
neutral_reviews = df_train[df_train["Polarity"] == 0]
positive_reviews = df_train[df_train["Polarity"] == 1]
print(negative_reviews.shape)
print(neutral_reviews.shape)
print(positive_reviews.shape)
# Out:
# (759, 8)
# (994, 8)
# (14666, 8)

# %% [markdown]
# # to balance the 3 classes:
# neutral = opinionated = 50%
#
# pos = negative = 25%
